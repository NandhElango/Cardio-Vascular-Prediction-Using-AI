# %% [markdown]
# <a href="https://colab.research.google.com/github/NandhElango/Cardio-Vascular-Prediction-Using-AI/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-8f3d3e8b-1d65-470c-9a1b-b5564dc256de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f3d3e8b-1d65-470c-9a1b-b5564dc256de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel("Online Retail.xlsx")
print(df.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
print(df.info())
print(df.describe())
print(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB
# None
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# ...

# %%
df=df.dropna()

# %%
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'])
df['year']=df['InvoiceDate'].dt.year
df['month']=df['InvoiceDate'].dt.month

# %%
df['TotalPrice']=df['Quantity']*df['UnitPrice']
total_revenue=df['TotalPrice'].sum()
print(total_revenue)
# Out:
# 8300065.814000001

# %%
top_products = df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(5)
print(top_products)
# Out:
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     53215
# JUMBO BAG RED RETROSPOT               45066
# ASSORTED COLOUR BIRD ORNAMENT         35314
# WHITE HANGING HEART T-LIGHT HOLDER    34147
# PACK OF 72 RETROSPOT CAKE CASES       33409
# Name: Quantity, dtype: int64

# %%
monthly_sales=df.groupby(['year','month'])['TotalPrice'].sum()
print(monthly_sales)
# Out:
# year  month
# 2010  12        554604.020
# 2011  1         475074.380
#       2         436546.150
#       3         579964.610
#       4         426047.851
#       5         648251.080
#       6         608013.160
#       7         574238.481
#       8         616368.000
#       9         931440.372
#       10        974603.590
#       11       1132407.740
#       12        342506.380
# Name: TotalPrice, dtype: float64

# %%
monthly_sales.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.title('Monthly Sales')
plt.show()

# %%
df.to_csv("cleaned online retailset.csv",index=False)

# %%
cleaned_data=pd.read_csv("cleaned online retailset.csv")
print(cleaned_data.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  year  month  \
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2010     12
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010     12
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom  2010     12
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010     12
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010     12
#
#    TotalPrice
# 0       15.30
# 1       20.34
# 2       22.00
# 3       20.34
# 4       20.34
